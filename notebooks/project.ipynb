# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !ls '/content/gdrive/My Drive/faceforensics++'
# Out:
# Mounted at /content/gdrive
# etc  faceforensics++

# %%
# OPTION1: USE EFFICIENTNET


import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, models, transforms
import os
import time
import copy
import numpy as np
import matplotlib.pyplot as plt


# data prep -> use torchvision.transforms , data augmentation, normalization etc

data_dir = '/content/gdrive/My Drive/faceforensics++'

# load data -> use DataLoader , then set batch, shuffle ..

# pretrained model : efficientnet (perhaps a simpler alternative:ResNet)
# version: b0-b12 (higher the better, but requires more computation), lite (mobile), v2 (latest) etc, easily interchangable
model = models.efficientnet_b0(weights=models.EfficientNet_B0_Weights.DEFAULT)

# use existing pretrained parameters
for param in model.parameters():
    param.requires_grad = False
# Out:
# '/device:GPU:0'

# %%
# OPTION 2: USE MODEL FROM GITHUB THAT USES XCEPTIONNET


# !git clone https://github.com/ondyari/faceforensics.git
# Out:
# Cloning into 'faceforensics'...
# remote: Enumerating objects: 414, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (32/32), done.
# remote: Total 414 (delta 29), reused 14 (delta 14), pack-reused 368 (from 1)
# Receiving objects: 100% (414/414), 59.81 MiB | 28.27 MiB/s, done.
# Resolving deltas: 100% (166/166), done.

# %%
# %cd /content/faceforensics/classification
# Out:
# /content/faceforensics/classification

# %%
# !pip install torch torchvision
# !pip install pandas
# !pip install tqdm
# !pip install facenet-pytorch

# %%
# test performance on adverserial dataset
# python detect_from_video.py
# -i <path to input video or folder of videos with extenstion '.mp4' or '.avi'>
# -m <path to model file, default is imagenet model
# -o <path to output folder, will contain output video(s)
# !python detect_from_video.py
# Out:
# dataset/  detect_from_video.py  network/  README.md  requirements.txt
